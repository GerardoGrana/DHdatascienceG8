# %% [markdown]
# # Preparando train_test

# %%
#Importamos librerias base
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Levanto los dataframes que voy a utilizar
PVR_observaciones = pd.read_csv('Data/PVR_observaciones.csv', encoding='latin1')
PVR_DAM_geodata = pd.read_csv('Data/PVR_DAM_geodata.csv', delimiter= ';')

#Borro los Nans de observaciones
PVR_observaciones.dropna(how='all', axis=1, inplace=True) 
PVR_observaciones.dropna(how='all', inplace= True)

print('Al comienzo: ', PVR_DAM_geodata['punto_tipo'].value_counts())
print('')
#Extraigo las esquinas quedandome solo con puntos verdes y ruleros en PVR_DAM_geodata
#Eliminamos las intersecciones
DAM_to_predict = PVR_DAM_geodata[PVR_DAM_geodata['punto_tipo'] == 'Intersercción']
PVR_geodata = PVR_DAM_geodata.drop(PVR_DAM_geodata[PVR_DAM_geodata['punto_tipo'] == 'Intersercción'].index)
PVR_observaciones = PVR_observaciones[['ClasificacionNum','ID']]
print('')
print('Finalmente: ',PVR_geodata['punto_tipo'].value_counts())
# Out:
# Al comienzo:  Intersercción    2386
# Rulero             40
# Punto verde        34
# Name: punto_tipo, dtype: int64
#
#
# Finalmente:  Rulero         40
# Punto verde    34
# Name: punto_tipo, dtype: int64

# %%
PVR_observaciones['ClasificacionNum'].value_counts()
# Out:
# 2.0    558
# 1.0    259
# 3.0      9
# Name: ClasificacionNum, dtype: int64

# %%
PVR_geodata
# Out:
#      ID   punto_tipo  poblacion  hogares  desocupado   0-14  65_mas  inicial  \
# 0   PV1  Punto verde      848.0    259.0        39.0  190.0    97.0     35.0
# 1   PV3  Punto verde      878.0    309.0        27.0  123.0   192.0     20.0
# 2   PV4  Punto verde     1018.0    346.0        46.0  182.0   195.0     40.0
# 3   PV5  Punto verde      778.0    239.0        31.0  170.0    82.0     26.0
# 4   PV6  Punto verde     1376.0    332.0        67.0  429.0   105.0     73.0
# ..  ...          ...        ...      ...         ...    ...     ...      ...
# 69  R39       Rulero      770.0    299.0        10.0   88.0   154.0     12.0
# 70  R40       Rulero      528.0    188.0        11.0   87.0   102.0     16.0
# 71  R41       Rulero      699.0    176.0        14.0   60.0   103.0     10.0
# 72  R43       Rulero      564.0    190.0        12.0   48.0   113.0      5.0
# 73  R42       Rulero      743.0    302.0        23.0  121.0    96.0     21.0
#
#     primario   egb  ...  NoLee_ni_e  hacinamiento  sin_agua  sin_cloaca  \
# 0      124.0  80.0  ...        40.0           1.0       0.0        23.0
# 1      115.0  38.0  ...        25.0           0.0       0.0         2.0
# 2      216.0  27.0  ...        58.0           2.0       0.0         2.0
# 3      163.0  55.0  ...        37.0           4.0       0.0         2.0
# 4      613.0  68.0  ...       116.0          20.0       0.0         8.0
# ..       ...   ...  ...         ...           ...       ...         ...
# 69      73.0  24.0  ...        14.0           0.0       0.0         2.0
# 70      40.0  24.0  ...        16.0           0.0       0.0         0.0
# 71     194.0  21.0  ...        30.0           0.0       0.0         0.0
# 72      56.0  16.0  ...        13.0           0.0       0.0         0.0
# 73     115.0  47.0  ...        32.0           2.0       0.0         1.0
#
#     densidad_comercial   microzonificacion  macrozonificacion          x  \
# 0                  0.0  Residencial urbano             Urbano -68.876163
# 1                  5.0  Residencial urbano             Urbano -68.853760
# 2                 12.0  Residencial urbano             Urbano -68.833320
# 3                 16.0  Residencial urbano             Urbano -68.825802
# 4                  3.0  Residencial urbano             Urbano -68.867890
# ..                 ...                 ...                ...        ...
# 69                26.0  Residencial urbano             Urbano -68.855060
# 70                10.0  Residencial urbano             Urbano -68.848370
# 71                36.0           Comercial   Altamente urbano -68.832310
# 72                19.0  Residencial urbano             Urbano -68.859146
# 73                 5.0           Comercial   Altamente urbano -68.829130
#
#             y  index
# 0  -32.868815      0
# 1  -32.866080      1
# 2  -32.862920      2
# 3  -32.871053      3
# 4  -32.869030      4
# ..        ...    ...
# 69 -32.885480     69
# 70 -32.901430     70
# 71 -32.893050     71
# 72 -32.896786     72
# 73 -32.884410     73
#
# [74 rows x 26 columns]

# %%
DAM_to_predict.dtypes
# Out:
# ID                     object
# punto_tipo             object
# poblacion             float64
# hogares               float64
# desocupado            float64
# 0-14                  float64
# 65_mas                float64
# inicial               float64
# primario              float64
# egb                   float64
# secundario            float64
# polimodal             float64
# superior              float64
# universitario         float64
# post_universitario    float64
# lee_y _esc            float64
# NoLee_ni_e            float64
# hacinamiento          float64
# sin_agua              float64
# sin_cloaca            float64
# densidad_comercial    float64
# microzonificacion      object
# macrozonificacion      object
# x                     float64
# y                     float64
# index                   int64
# dtype: object

# %%
#Genero el DataFrame final
PVR_train_test = pd.merge(PVR_observaciones, PVR_geodata , how="left", on=["ID"]) 
PVR_train_test
# Out:
#      ClasificacionNum    ID   punto_tipo  poblacion  hogares  desocupado  \
# 0                 1.0  PV11  Punto verde      620.0    215.0        17.0
# 1                 1.0  PV11  Punto verde      620.0    215.0        17.0
# 2                 1.0  PV11  Punto verde      620.0    215.0        17.0
# 3                 1.0   PV7  Punto verde      985.0    375.0        38.0
# 4                 1.0   PV7  Punto verde      985.0    375.0        38.0
# ..                ...   ...          ...        ...      ...         ...
# 846               2.0   R40       Rulero      528.0    188.0        11.0
# 847               2.0   R40       Rulero      528.0    188.0        11.0
# 848               2.0   R40       Rulero      528.0    188.0        11.0
# 849               2.0   R40       Rulero      528.0    188.0        11.0
# 850               2.0   R40       Rulero      528.0    188.0        11.0
#
#       0-14  65_mas  inicial  primario  ...  NoLee_ni_e  hacinamiento  \
# 0    101.0   103.0     16.0      79.0  ...        22.0           1.0
# 1    101.0   103.0     16.0      79.0  ...        22.0           1.0
# 2    101.0   103.0     16.0      79.0  ...        22.0           1.0
# 3    161.0   145.0     28.0     166.0  ...        35.0           1.0
# 4    161.0   145.0     28.0     166.0  ...        35.0           1.0
# ..     ...     ...      ...       ...  ...         ...           ...
# 846   87.0   102.0     16.0      40.0  ...        16.0           0.0
# 847   87.0   102.0     16.0      40.0  ...        16.0           0.0
# 848   87.0   102.0     16.0      40.0  ...        16.0           0.0
# 849   87.0   102.0     16.0      40.0  ...        16.0           0.0
# 850   87.0   102.0     16.0      40.0  ...        16.0           0.0
#
#      sin_agua  sin_cloaca  densidad_comercial   microzonificacion  \
# 0         0.0         0.0                 7.0  Residencial urbano
# 1         0.0         0.0                 7.0  Residencial urbano
# 2         0.0         0.0                 7.0  Residencial urbano
# 3         0.0         3.0                17.0  Residencial urbano
# 4         0.0         3.0                17.0  Residencial urbano
# ..        ...         ...                 ...                 ...
# 846       0.0         0.0                10.0  Residencial urbano
# 847       0.0         0.0                10.0  Residencial urbano
# 848       0.0         0.0                10.0  Residencial urbano
# 849       0.0         0.0                10.0  Residencial urbano
# 850       0.0         0.0                10.0  Residencial urbano
#
#      macrozonificacion         x         y  index
# 0               Urbano -68.85207 -32.87347   10.0
# 1               Urbano -68.85207 -32.87347   10.0
# 2               Urbano -68.85207 -32.87347   10.0
# 3               Urbano -68.84756 -32.87072    5.0
# 4               Urbano -68.84756 -32.87072    5.0
# ..                 ...       ...       ...    ...
# 846             Urbano -68.84837 -32.90143   70.0
# 847             Urbano -68.84837 -32.90143   70.0
# 848             Urbano -68.84837 -32.90143   70.0
# 849             Urbano -68.84837 -32.90143   70.0
# 850             Urbano -68.84837 -32.90143   70.0
#
# [851 rows x 27 columns]

# %%
#Miremos los features y los nulos
print(PVR_train_test.isnull().sum())
#Eliminamos los nulls en todas las columnas
PVR_train_test.dropna(axis=0, inplace= True)
# Out:
# ClasificacionNum       0
# ID                     0
# punto_tipo            36
# poblacion             36
# hogares               36
# desocupado            36
# 0-14                  36
# 65_mas                36
# inicial               36
# primario              36
# egb                   36
# secundario            36
# polimodal             36
# superior              36
# universitario         36
# post_universitario    36
# lee_y _esc            36
# NoLee_ni_e            36
# hacinamiento          36
# sin_agua              36
# sin_cloaca            36
# densidad_comercial    43
# microzonificacion     36
# macrozonificacion     36
# x                     36
# y                     36
# index                 36
# dtype: int64

# %%
#Miramos nuevamente los nulos
print(PVR_train_test.isnull().sum())
print('')
print('Se eliminaron correctamente :)')
# Out:
# ClasificacionNum      0
# ID                    0
# punto_tipo            0
# poblacion             0
# hogares               0
# desocupado            0
# 0-14                  0
# 65_mas                0
# inicial               0
# primario              0
# egb                   0
# secundario            0
# polimodal             0
# superior              0
# universitario         0
# post_universitario    0
# lee_y _esc            0
# NoLee_ni_e            0
# hacinamiento          0
# sin_agua              0
# sin_cloaca            0
# densidad_comercial    0
# microzonificacion     0
# macrozonificacion     0
# x                     0
# y                     0
# index                 0
# dtype: int64
#
# Se eliminaron correctamente :)

# %%
#Binarizamos la columna de calidad 
diccionario = {1.0: 1.0, 2.0: 0, 3.0 : 0}
PVR_train_test['ClasificacionNum']= PVR_train_test['ClasificacionNum'].map(diccionario)
PVR_train_test = PVR_train_test.rename(columns={'ClasificacionNum':'Target'})
#Eliminamos los NaN
PVR_train_test.dropna(axis=0, inplace=True)

# %%
PVR_train_test['Target'].value_counts()
# Out:
# 0.0    560
# 1.0    248
# Name: Target, dtype: int64

# %%
#Veamos la matriz de correlación
corr_df = PVR_train_test.corr(method='pearson')

corr_df.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_a790e3ed_3549_11ed_8424_d45d64585146row1_col7,#T_a790e3ed_3549_11ed_8424_d45d64585146row9_col10,#T_a790e3ed_3549_11ed_8424_d45d64585146row10_col2,#T_a790e3ed_3549_11ed_8424_d45d64585146row10_col9{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_a790e3ed_3549_11ed_8424_d45d64585146row1_col8,#T_a790e3ed_3549_11ed_8424_d45d64585146row3_col15{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_a790e3ed_3549_11ed_8424_d45d64585146row1_col9,#T_a790e3ed_3549_11ed_8424_d45d64585146row6_col14{
#             background-color:  #d95847;
#             color:  #000000;
#         }#T_a790e3ed_3549_11ed_8424_d45d64585146row1_col11,#T_a790e3ed_3549_11ed_8424_d45d64585146row4_col8{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_a790e3ed_3549_11ed_8424_d45d64585146row1_col12,#T_a790e3ed_3549_11ed_8424_d45d64585146row4_col11,#T_a790e3ed_3549_11ed_8424_d45d64585146row7_col6,#T_a790e3ed_3549_11ed_8424_d45d64585146row7_col14{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_a790e3ed_3549_11ed_8424_d45d64585146row1_col13,#T_a790e3ed_3549_11ed_8424_d45d64585146row9_col5,#T_a790e3ed_3549_11ed_8424_d45d64585146row18_col8{
#             background-color:  #f7ba9f;

# %%
PVR_train_test.dtypes
# Out:
# Target                 object
# ID                     object
# punto_tipo             object
# poblacion             float64
# hogares               float64
# desocupado            float64
# 0-14                  float64
# 65_mas                float64
# inicial               float64
# primario              float64
# egb                   float64
# secundario            float64
# polimodal             float64
# superior              float64
# universitario         float64
# post_universitario    float64
# lee_y _esc            float64
# NoLee_ni_e            float64
# hacinamiento          float64
# sin_agua              float64
# sin_cloaca            float64
# densidad_comercial    float64
# microzonificacion      object
# macrozonificacion      object
# x                     float64
# y                     float64
# index                 float64
# dtype: object

# %%
#Vamos a eliminar columnas que son irrelevantes o que tienen mucha correlación con otras
PVR_train_test_copy = PVR_train_test.copy()
PVR_train_test.drop(['ID', 'index','x','y', 'punto_tipo'], axis=1, inplace= True)

# %%
PVR_train_test.dtypes
# Out:
# Target                float64
# poblacion             float64
# hogares               float64
# desocupado            float64
# 0-14                  float64
# 65_mas                float64
# inicial               float64
# primario              float64
# egb                   float64
# secundario            float64
# polimodal             float64
# superior              float64
# universitario         float64
# post_universitario    float64
# lee_y _esc            float64
# NoLee_ni_e            float64
# hacinamiento          float64
# sin_agua              float64
# sin_cloaca            float64
# densidad_comercial    float64
# microzonificacion      object
# macrozonificacion      object
# dtype: object

# %%
#Hacemos dummies
PVR_train_test = pd.get_dummies(PVR_train_test, drop_first=True)

# %%
PVR_train_test
# Out:
#      Target  poblacion  hogares  desocupado   0-14  65_mas  inicial  primario  \
# 0       1.0      620.0    215.0        17.0  101.0   103.0     16.0      79.0
# 1       1.0      620.0    215.0        17.0  101.0   103.0     16.0      79.0
# 2       1.0      620.0    215.0        17.0  101.0   103.0     16.0      79.0
# 3       1.0      985.0    375.0        38.0  161.0   145.0     28.0     166.0
# 4       1.0      985.0    375.0        38.0  161.0   145.0     28.0     166.0
# ..      ...        ...      ...         ...    ...     ...      ...       ...
# 846     0.0      528.0    188.0        11.0   87.0   102.0     16.0      40.0
# 847     0.0      528.0    188.0        11.0   87.0   102.0     16.0      40.0
# 848     0.0      528.0    188.0        11.0   87.0   102.0     16.0      40.0
# 849     0.0      528.0    188.0        11.0   87.0   102.0     16.0      40.0
# 850     0.0      528.0    188.0        11.0   87.0   102.0     16.0      40.0
#
#       egb  secundario  ...  NoLee_ni_e  hacinamiento  sin_agua  sin_cloaca  \
# 0    42.0       156.0  ...        22.0           1.0       0.0         0.0
# 1    42.0       156.0  ...        22.0           1.0       0.0         0.0
# 2    42.0       156.0  ...        22.0           1.0       0.0         0.0
# 3    47.0       198.0  ...        35.0           1.0       0.0         3.0
# 4    47.0       198.0  ...        35.0           1.0       0.0         3.0
# ..    ...         ...  ...         ...           ...       ...         ...
# 846  24.0        82.0  ...        16.0           0.0       0.0         0.0
# 847  24.0        82.0  ...        16.0           0.0       0.0         0.0
# 848  24.0        82.0  ...        16.0           0.0       0.0         0.0
# 849  24.0        82.0  ...        16.0           0.0       0.0         0.0
# 850  24.0        82.0  ...        16.0           0.0       0.0         0.0
#
#      densidad_comercial  microzonificacion_Comercial  \
# 0                   7.0                            0
# 1                   7.0                            0
# 2                   7.0                            0
# 3                  17.0                            0
# 4                  17.0                            0
# ..                  ...                          ...
# 846                10.0                            0
# 847                10.0                            0
# 848                10.0                            0
# 849                10.0                            0
# 850                10.0                            0
#
#      microzonificacion_Residencial suburbano  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 846                                        0
# 847                                        0
# 848                                        0
# 849                                        0
# 850                                        0
#
#      microzonificacion_Residencial urbano  macrozonificacion_Interfaz  \
# 0                                       1                           0
# 1                                       1                           0
# 2                                       1                           0
# 3                                       1                           0
# 4                                       1                           0
# ..                                    ...                         ...
# 846                                     1                           0
# 847                                     1                           0
# 848                                     1                           0
# 849                                     1                           0
# 850                                     1                           0
#
#      macrozonificacion_Urbano
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 846                         1
# 847                         1
# 848                         1
# 849                         1
# 850                         1
#
# [808 rows x 25 columns]

# %%
#Lo guardamos
PVR_train_test['punto_tipo'] = PVR_train_test_copy['punto_tipo']
PVR_train_test['ID'] = PVR_train_test_copy['ID']
PVR_train_test['x'] = PVR_train_test_copy['x']
PVR_train_test['y'] = PVR_train_test_copy['y']
PVR_train_test.to_csv("PVR_train_test.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Preparación predicciones
# Para poner a prueba el modelo antes del deploy.
# Se realizarán predicciones sobre todos los cruces de calles de la ciudad para evaluar cuales serían zonas interesantes.
#
# NOTA: cada intersección de calles debería tener una predicción similar al punto verde más cercano. Para evaluar esto se deberá crear una vista de mapa y posiblemente una métrica customizada que explique la calidad de las predicciones aplicando algún criterio espacial.

# %%
DAM_to_predict = DAM_to_predict[
       [#'ID',
       'poblacion', 
       '0-14', 
       'primario', 
       'secundario', 
       'polimodal',
       'lee_y _esc', 
       'NoLee_ni_e', 
       ]
       ]
DAM_to_predict
# Out:
#       poblacion   0-14  primario  secundario  polimodal  lee_y _esc  \
# 74        845.0  186.0     190.0       279.0       42.0       753.0
# 75        958.0  207.0     174.0       276.0       73.0       868.0
# 76        845.0  186.0     190.0       279.0       42.0       753.0
# 77        845.0  186.0     190.0       279.0       42.0       753.0
# 78        845.0  186.0     190.0       279.0       42.0       753.0
# ...         ...    ...       ...         ...        ...         ...
# 2455      340.0   31.0      26.0        63.0       19.0       323.0
# 2456        5.0    0.0       4.0         0.0        0.0         3.0
# 2457        5.0    0.0       4.0         0.0        0.0         3.0
# 2458        5.0    0.0       4.0         0.0        0.0         3.0
# 2459      745.0  213.0     317.0       201.0       20.0       626.0
#
#       NoLee_ni_e
# 74          42.0
# 75          45.0
# 76          42.0
# 77          42.0
# 78          42.0
# ...          ...
# 2455         8.0
# 2456         2.0
# 2457         2.0
# 2458         2.0
# 2459        58.0
#
# [2386 rows x 7 columns]

# %%
DAM_to_predict.dropna( axis=0, inplace=True)

# %%
DAM_to_predict.isnull().sum()
# Out:
# poblacion     0
# 0-14          0
# primario      0
# secundario    0
# polimodal     0
# lee_y _esc    0
# NoLee_ni_e    0
# dtype: int64

# %%
DAM_to_predict.to_csv("DAM_to_predict.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Reclasificación de variable punto_tipo
# Dentro del dataframe DAM_to_predict la columna punto_tipo contiene el valor 'Intersección'.
# Para realizar la predicción, se reclasificará este valor con dos alternativas: 'Punto verde' y 'Rulero'.
# El objetivo de esto es poder analizar la predicción de la intersección preguntándole al algoritmo cómo se comportaría ese lugar si fuera PR o R.
# Por lo tanto se duplicará el df DAM_to_predict (copy):
# * DAM_to_predict_R
# * DAM_to_predict_PV
# Luego se apilarán ambos df en uno único llamado DAM_predictions.

# %%
DAM_to_predict_R = DAM_to_predict.copy(deep=True)

diccionarioR = {'Intersercción':'Rulero'}
DAM_to_predict_R['punto_tipo'] = DAM_to_predict_R['punto_tipo'].map(diccionarioR)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\indexes\base.py:2898, in Index.get_loc(self, key, method, tolerance)
#    2897 try:
# -> 2898     return self._engine.get_loc(casted_key)
#    2899 except KeyError as err:
#
# File pandas\_libs\index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:1675, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:1683, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'punto_tipo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [27], in <cell line: 4>()
#       1 DAM_to_predict_R = DAM_to_predict.copy(deep=True)
#       3 diccionarioR = {'Intersercción':'Rulero'}
# ----> 4 DAM_to_predict_R['punto_tipo'] = DAM_to_predict_R['punto_tipo'].map(diccionarioR)
#
# File ~\anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\frame.py:2906, in DataFrame.__getitem__(self, key)
#    2904 if self.columns.nlevels > 1:
#    2905     return self._getitem_multilevel(key)
# -> 2906 indexer = self.columns.get_loc(key)
#    2907 if is_integer(indexer):
#    2908     indexer = [indexer]
#
# File ~\anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\indexes\base.py:2900, in Index.get_loc(self, key, method, tolerance)
#    2898         return self._engine.get_loc(casted_key)
#    2899     except KeyError as err:
# -> 2900         raise KeyError(key) from err
#    2902 if tolerance is not None:
#    2903     tolerance = self._convert_tolerance(tolerance, np.asarray(key))
#
# KeyError: 'punto_tipo'

# %%
DAM_to_predict_R
# Out:
#          ID  poblacion   0-14  primario  secundario  polimodal  lee_y _esc  \
# 74       I1      845.0  186.0     190.0       279.0       42.0       753.0
# 75       I2      958.0  207.0     174.0       276.0       73.0       868.0
# 76       I3      845.0  186.0     190.0       279.0       42.0       753.0
# 77       I4      845.0  186.0     190.0       279.0       42.0       753.0
# 78       I5      845.0  186.0     190.0       279.0       42.0       753.0
# ...     ...        ...    ...       ...         ...        ...         ...
# 2455  I2382      340.0   31.0      26.0        63.0       19.0       323.0
# 2456  I2383        5.0    0.0       4.0         0.0        0.0         3.0
# 2457  I2384        5.0    0.0       4.0         0.0        0.0         3.0
# 2458  I2385        5.0    0.0       4.0         0.0        0.0         3.0
# 2459  I2386      745.0  213.0     317.0       201.0       20.0       626.0
#
#       NoLee_ni_e punto_tipo
# 74          42.0     Rulero
# 75          45.0     Rulero
# 76          42.0     Rulero
# 77          42.0     Rulero
# 78          42.0     Rulero
# ...          ...        ...
# 2455         8.0     Rulero
# 2456         2.0     Rulero
# 2457         2.0     Rulero
# 2458         2.0     Rulero
# 2459        58.0     Rulero
#
# [2386 rows x 9 columns]

# %%
DAM_to_predict_R= pd.get_dummies(DAM_to_predict_R)

# %%
diccionario = {1:0}
DAM_to_predict_PV = DAM_to_predict_R.copy(deep=True)

# %%
DAM_to_predict_PV['punto_tipo_Rulero'] = DAM_to_predict_PV['punto_tipo_Rulero'].map(diccionario)

# %%
#Borro los Nans de PV y R
DAM_to_predict_PV.dropna( axis=0, inplace=True) 
DAM_to_predict_R.dropna( axis=0, inplace= True)

# %%
DAM_to_predict_R.isnull().sum()
# Out:
# poblacion            0
# 0-14                 0
# primario             0
# secundario           0
# polimodal            0
#                     ..
# ID_I996              0
# ID_I997              0
# ID_I998              0
# ID_I999              0
# punto_tipo_Rulero    0
# Length: 2394, dtype: int64

# %%
#Los guardamos
DAM_to_predict_PV.to_csv("DAM_to_predict_PV.csv", index=False, encoding='utf-8-sig')
DAM_to_predict_R.to_csv("DAM_to_predict_R.csv", index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 #Los guardamos
# ----> 2 DAM_to_predict_PV.to_csv("DAM_to_predict_PV.csv", index=False, encoding='utf-8-sig')
#       3 DAM_to_predict_R.to_csv("DAM_to_predict_R.csv", index=False, encoding='utf-8-sig')
#       4 DAM_to_predict.to_csv("DAM_to_predict.csv", index=False, encoding='utf-8-sig')
#
# NameError: name 'DAM_to_predict_PV' is not defined
